# %% [markdown]
# <a href="https://colab.research.google.com/github/wahyuherdiansyah32-maker/tugas-steganografi/blob/main/TugasStegonografi.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pillow

# %%
from google.colab import files
uploaded = files.upload()
from PIL import Image

def text_to_binary(text):
    return ''.join(format(ord(i), '08b') for i in text)

def encode_image(image_path, secret_text, output_path):
    img = Image.open(image_path)
    img = img.convert('RGB')
    pixels = list(img.getdata())

    binary_text = text_to_binary(secret_text) + '1111111111111110'  # penanda akhir
    new_pixels = []

    data_index = 0
    for pixel in pixels:
        r, g, b = pixel

        if data_index < len(binary_text):
            r = (r & ~1) | int(binary_text[data_index])
            data_index += 1
        if data_index < len(binary_text):
            g = (g & ~1) | int(binary_text[data_index])
            data_index += 1
        if data_index < len(binary_text):
            b = (b & ~1) | int(binary_text[data_index])
            data_index += 1

        new_pixels.append((r, g, b))

    img.putdata(new_pixels)
    img.save(output_path)

    print("✅ Data berhasil disembunyikan!")
# Out:
#      <input type="file" id="files-b0e06fb5-08ed-4e0c-a36f-e87318895574" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-b0e06fb5-08ed-4e0c-a36f-e87318895574">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from PIL import Image

def text_to_binary(text):
    return ''.join(format(ord(i), '08b') for i in text)

def encode_image(image_path, secret_text, output_path):
    img = Image.open(image_path)
    img = img.convert('RGB')
    pixels = list(img.getdata())

    binary_text = text_to_binary(secret_text) + '1111111111111110'
    new_pixels = []

    data_index = 0
    for pixel in pixels:
        r, g, b = pixel

        if data_index < len(binary_text):
            r = (r & ~1) | int(binary_text[data_index])
            data_index += 1
        if data_index < len(binary_text):
            g = (g & ~1) | int(binary_text[data_index])
            data_index += 1
        if data_index < len(binary_text):
            b = (b & ~1) | int(binary_text[data_index])
            data_index += 1

        new_pixels.append((r, g, b))

    img.putdata(new_pixels)
    img.save(output_path)

    print("✅ Data berhasil disembunyikan!")

def decode_image(image_path):
    img = Image.open(image_path)
    pixels = list(img.getdata())

    binary_data = ""

    for pixel in pixels:
        for color in pixel:
            binary_data += str(color & 1)

    all_bytes = [binary_data[i:i+8] for i in range(0, len(binary_data), 8)]

    decoded_text = ""
    for byte in all_bytes:
        if byte == '11111110':
            break
        decoded_text += chr(int(byte, 2))

    print("🔍 Hasil ekstraksi:", decoded_text)

# %%
encode_image("gambar.png", "Nama Kelompok :Wahyu herdiansyah,Tolhah Alfayadh,Supriadin", "gambar_stego.png")
# Out:
# ✅ Data berhasil disembunyikan!

# %%
from google.colab import files
files.download("gambar_stego.png")

# %%
decode_image("gambar_stego.png")
# Out:
# 🔍 Hasil ekstraksi: Nama Kelompok :Wahyu herdiansyah,Tolhah Alfayadh,Supriadinÿ
